# %% [markdown]
# # ChestSight: Multi-Label Pathology Detection from Chest X-Rays
#
# **Author:** Amit Tiwari
# **Institution:** University of Salford — MSc Data Science (2025)
# **Dataset:** NIH ChestX-ray14 ([Kaggle](https://www.kaggle.com/datasets/nih-chest-xrays/data))
# **Architecture:** DenseNet-121 with ImageNet pre-training
# **Framework:** TensorFlow / Keras
#
# ---
#
# ## Overview
#
# This notebook implements an end-to-end pipeline for automated detection of 14 thoracic pathologies from frontal chest X-rays. All outputs — plots, metrics CSVs, model weights, and Grad-CAM heatmaps — are saved into an organised `results/` folder hierarchy.
#
# ```
# results/
# ├── eda/              # Exploratory data analysis plots
# ├── training/         # Training curves and history CSV
# ├── evaluation/       # Classification report, per-class metrics CSV
# ├── explainability/   # Grad-CAM heatmaps
# └── models/           # Best model weights checkpoint
# ```
#
# > **Dataset note:** Download the NIH ChestX-ray14 dataset from Kaggle and place it under `DATA_DIR` before running cells beyond Section 2.

# %% [markdown]
# ## 1. Configuration & Imports

# %%
# ── Standard library ──────────────────────────────────────────────────────────
import os
import json
import random
import warnings
warnings.filterwarnings('ignore')

# ── Scientific computing ───────────────────────────────────────────────────────
import numpy as np
import pandas as pd

# ── Deep learning ──────────────────────────────────────────────────────────────
import tensorflow as tf
from tensorflow.keras.applications import DenseNet121
from tensorflow.keras import layers, models, optimizers, callbacks
from tensorflow.keras.layers import GlobalAveragePooling2D, Dropout, Dense
from tensorflow.keras.models import Model

# ── Image processing ───────────────────────────────────────────────────────────
import cv2

# ── Visualisation ──────────────────────────────────────────────────────────────
import matplotlib.pyplot as plt
import seaborn as sns

# ── Metrics ────────────────────────────────────────────────────────────────────
from sklearn.metrics import classification_report, jaccard_score, f1_score

# ── Reproducibility ────────────────────────────────────────────────────────────
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

print(f"TensorFlow version : {tf.__version__}")
print(f"GPU available      : {len(tf.config.list_physical_devices('GPU')) > 0}")

# %% [markdown]
# ### 1.1 Project Configuration
#
# All paths and hyperparameters are declared here. Update `DATA_DIR` to point to your local dataset directory.

# %%
# ══════════════════════════════════════════════════════════════════════════════
# PATHS — update DATA_DIR before running
# ══════════════════════════════════════════════════════════════════════════════
DATA_DIR  = "data"                                    # <-- update this path
CSV_PATH  = os.path.join(DATA_DIR, "Data_Entry_2017_v2020.csv")
IMAGE_DIR = os.path.join(DATA_DIR, "images")

# ── Results folder hierarchy ───────────────────────────────────────────────────
RESULTS_DIR         = "results"
EDA_DIR             = os.path.join(RESULTS_DIR, "eda")
TRAINING_DIR        = os.path.join(RESULTS_DIR, "training")
EVALUATION_DIR      = os.path.join(RESULTS_DIR, "evaluation")
EXPLAINABILITY_DIR  = os.path.join(RESULTS_DIR, "explainability")
MODELS_DIR          = os.path.join(RESULTS_DIR, "models")
MODEL_PATH          = os.path.join(MODELS_DIR, "chestsight_best.weights.h5")

# Create all directories
for d in [EDA_DIR, TRAINING_DIR, EVALUATION_DIR, EXPLAINABILITY_DIR, MODELS_DIR]:
    os.makedirs(d, exist_ok=True)

print("Results folder structure created:")
for root, dirs, files in os.walk(RESULTS_DIR):
    level = root.replace(RESULTS_DIR, '').count(os.sep)
    indent = '    ' * level
    print(f"{indent}{os.path.basename(root)}/")

# ══════════════════════════════════════════════════════════════════════════════
# IMAGE SETTINGS
# ══════════════════════════════════════════════════════════════════════════════
IMG_SIZE  = 224     # DenseNet-121 expected input size
CHANNELS  = 3

# ══════════════════════════════════════════════════════════════════════════════
# TRAINING HYPERPARAMETERS
# ══════════════════════════════════════════════════════════════════════════════
BATCH_SIZE    = 16
EPOCHS        = 10
LEARNING_RATE = 1e-4
DROPOUT_RATE  = 0.5
FINETUNE_FROM = "conv5_block16_concat"   # Unfreeze DenseNet-121 from this layer

# ══════════════════════════════════════════════════════════════════════════════
# DATA SPLIT RATIOS
# ══════════════════════════════════════════════════════════════════════════════
TRAIN_RATIO = 0.70
VAL_RATIO   = 0.10
TEST_RATIO  = 0.20

# ══════════════════════════════════════════════════════════════════════════════
# IMAGENET NORMALISATION CONSTANTS
# ══════════════════════════════════════════════════════════════════════════════
IMAGENET_MEAN = [0.485, 0.456, 0.406]
IMAGENET_STD  = [0.229, 0.224, 0.225]

print(f"\nConfiguration loaded successfully.")
print(f"  Data directory : {DATA_DIR}")
print(f"  Image size     : {IMG_SIZE}x{IMG_SIZE}x{CHANNELS}")
print(f"  Batch size     : {BATCH_SIZE}  |  Epochs: {EPOCHS}")
print(f"  Learning rate  : {LEARNING_RATE}  |  Dropout: {DROPOUT_RATE}")

# %% [markdown]
# ## 2. Data Loading & Label Encoding

# %%
# ── Load metadata CSV ──────────────────────────────────────────────────────────
df = pd.read_csv(CSV_PATH)
print(f"Dataset loaded : {len(df):,} records  |  {df.shape[1]} columns")
print(f"Columns        : {df.columns.tolist()}")
df.head()

# %%
# ── Extract and sort unique labels ────────────────────────────────────────────
all_labels = set()
for label_str in df['Finding Labels']:
    for label in label_str.split('|'):
        all_labels.add(label.strip())

all_labels = sorted(list(all_labels))
label2idx  = {label: idx for idx, label in enumerate(all_labels)}
num_labels = len(all_labels)

print(f"Unique labels ({num_labels}): {all_labels}")


# ── Multi-hot encoding ─────────────────────────────────────────────────────────
def encode_labels(label_str: str) -> np.ndarray:
    """Convert a pipe-delimited label string to a multi-hot binary vector."""
    label_vector = np.zeros(num_labels, dtype=np.float32)
    for label in label_str.split('|'):
        label = label.strip()
        if label in label2idx:
            label_vector[label2idx[label]] = 1.0
    return label_vector

df['encoded'] = df['Finding Labels'].apply(encode_labels)
print(f"\nLabel encoding complete. Vector shape: {df['encoded'].iloc[0].shape}")

# %% [markdown]
# ## 3. Exploratory Data Analysis (EDA)
#
# All plots in this section are saved to `results/eda/`.
#
# ### 3.1 Dataset Overview

# %%
print("── DataFrame Info ──────────────────────────────────────────────────────────")
print(df.info())
print("\n── Missing Values ──────────────────────────────────────────────────────────")
print(df.isnull().sum())
print("\n── Numerical Summary ───────────────────────────────────────────────────────")
print(df.describe())

# %% [markdown]
# ### 3.2 Label Frequency Distribution

# %%
# ── Per-label frequencies ──────────────────────────────────────────────────────
label_frequencies = {}
for label_str in df['Finding Labels']:
    for label in label_str.split('|'):
        label = label.strip()
        label_frequencies[label] = label_frequencies.get(label, 0) + 1

total_images = len(df)
label_df = (
    pd.DataFrame.from_dict(label_frequencies, orient='index', columns=['Count'])
    .assign(Percentage=lambda x: (x['Count'] / total_images * 100).round(2))
    .sort_values('Count', ascending=False)
)

# Save frequency table as CSV
label_df.to_csv(os.path.join(EDA_DIR, "label_frequencies.csv"))
print(label_df.to_string())

# ── Bar chart ──────────────────────────────────────────────────────────────────
fig, ax = plt.subplots(figsize=(14, 5))
bars = ax.bar(label_df.index, label_df['Count'],
              color='steelblue', edgecolor='white', linewidth=0.6)
ax.bar_label(bars, labels=[f"{v:,}" for v in label_df['Count']],
             padding=3, fontsize=8, color='#444')
ax.set_xlabel("Pathology", fontsize=12)
ax.set_ylabel("Image Count", fontsize=12)
ax.set_title("Label Frequency Distribution — NIH ChestX-ray14",
             fontsize=14, fontweight='bold', pad=12)
ax.tick_params(axis='x', rotation=45)
sns.despine()
plt.tight_layout()
save_path = os.path.join(EDA_DIR, "01_label_distribution.png")
plt.savefig(save_path, dpi=150, bbox_inches='tight')
plt.show()
print(f"Saved → {save_path}")

# %% [markdown]
# ### 3.3 Multi-label Co-occurrence

# %%
# ── Labels-per-image breakdown ────────────────────────────────────────────────
label_counts_per_image = df['Finding Labels'].str.split('|').apply(len)
single    = (label_counts_per_image == 1).sum()
double    = (label_counts_per_image == 2).sum()
triple    = (label_counts_per_image == 3).sum()
quad_plus = (label_counts_per_image >= 4).sum()

print("Labels per image:")
print(f"  Single  : {single:>6,}  ({single/total_images*100:.2f}%)")
print(f"  Double  : {double:>6,}  ({double/total_images*100:.2f}%)")
print(f"  Triple  : {triple:>6,}  ({triple/total_images*100:.2f}%)")
print(f"  4+      : {quad_plus:>6,}  ({quad_plus/total_images*100:.2f}%)")

fig, ax = plt.subplots(figsize=(6, 6))
ax.pie(
    [single, double, triple, quad_plus],
    labels=['Single', 'Double', 'Triple', '4+'],
    autopct='%1.1f%%', startangle=60,
    explode=(0.05, 0, 0, 0),
    colors=['#4C72B0', '#DD8452', '#55A868', '#C44E52']
)
ax.set_title("Label Count Distribution per Image",
             fontsize=13, fontweight='bold', pad=12)
plt.tight_layout()
save_path = os.path.join(EDA_DIR, "02_multilabel_distribution.png")
plt.savefig(save_path, dpi=150, bbox_inches='tight')
plt.show()
print(f"Saved → {save_path}")

# %% [markdown]
# ### 3.4 Patient Demographics

# %%
fig, axes = plt.subplots(1, 3, figsize=(18, 5))

# Gender
gender_pct = df['Patient Gender'].value_counts() / total_images * 100
axes[0].pie(gender_pct, labels=gender_pct.index, autopct='%1.1f%%',
            colors=['#4C72B0', '#DD8452'], startangle=90)
axes[0].set_title("Gender Distribution", fontsize=12, fontweight='bold')

# View position
view_pct = df['View Position'].value_counts() / total_images * 100
axes[1].pie(view_pct, labels=view_pct.index, autopct='%1.1f%%',
            colors=['#55A868', '#C44E52'], startangle=90)
axes[1].set_title("View Position Distribution", fontsize=12, fontweight='bold')

# Age
axes[2].hist(df['Patient Age'], bins=range(0, 100, 5),
             color='steelblue', edgecolor='white')
axes[2].set_xlabel("Age", fontsize=11)
axes[2].set_ylabel("Frequency", fontsize=11)
axes[2].set_title("Patient Age Distribution", fontsize=12, fontweight='bold')
sns.despine(ax=axes[2])

plt.suptitle("Patient Demographics — NIH ChestX-ray14",
             fontsize=14, fontweight='bold', y=1.02)
plt.tight_layout()
save_path = os.path.join(EDA_DIR, "03_demographics.png")
plt.savefig(save_path, dpi=150, bbox_inches='tight')
plt.show()
print(f"Saved → {save_path}")

# %% [markdown]
# ### 3.5 Label Co-occurrence Heatmap

# %%
# ── Co-occurrence matrix ───────────────────────────────────────────────────────
co_occurrence = np.zeros((num_labels, num_labels))
for _, row in df.iterrows():
    lbls = [l.strip() for l in row['Finding Labels'].split('|')]
    for i in range(len(lbls)):
        for j in range(i + 1, len(lbls)):
            if lbls[i] in label2idx and lbls[j] in label2idx:
                co_occurrence[label2idx[lbls[i]], label2idx[lbls[j]]] += 1
                co_occurrence[label2idx[lbls[j]], label2idx[lbls[i]]] += 1

co_occurrence_df   = pd.DataFrame(co_occurrence, index=all_labels, columns=all_labels)
correlation_matrix = co_occurrence_df.corr()

# Save correlation matrix
correlation_matrix.to_csv(os.path.join(EDA_DIR, "label_cooccurrence_correlation.csv"))

fig, ax = plt.subplots(figsize=(14, 11))
mask = np.triu(np.ones_like(correlation_matrix, dtype=bool))
sns.heatmap(
    correlation_matrix, mask=mask, annot=True, fmt=".2f",
    cmap='coolwarm', center=0, linewidths=0.5,
    annot_kws={"size": 7}, ax=ax
)
ax.set_title("Label Co-occurrence Correlation Matrix",
             fontsize=14, fontweight='bold', pad=12)
plt.tight_layout()
save_path = os.path.join(EDA_DIR, "04_cooccurrence_heatmap.png")
plt.savefig(save_path, dpi=150, bbox_inches='tight')
plt.show()
print(f"Saved → {save_path}")

# %% [markdown]
# ### 3.6 Sample Images per Pathology

# %%
selected = {}
for label in all_labels:
    subset = df[df['Finding Labels'].str.contains(label, regex=False)]
    if len(subset) >= 2:
        selected[label] = random.sample(list(subset['Image Index']), 2)

image_indices = [img for imgs in selected.values() for img in imgs]
num_cols = 4
num_rows = (len(image_indices) + num_cols - 1) // num_cols

fig, axes = plt.subplots(num_rows, num_cols, figsize=(20, num_rows * 5))
axes = axes.ravel()

for i, image_index in enumerate(image_indices):
    img_path = os.path.join(IMAGE_DIR, image_index)
    try:
        img = plt.imread(img_path)
        axes[i].imshow(img, cmap='gray')
        finding = df.loc[df['Image Index'] == image_index, 'Finding Labels'].iloc[0]
        axes[i].set_title(finding, fontsize=8)
    except FileNotFoundError:
        axes[i].text(0.5, 0.5, 'Image not found', ha='center', va='center',
                     transform=axes[i].transAxes, color='gray')
    axes[i].axis('off')

for j in range(len(image_indices), len(axes)):
    axes[j].axis('off')

plt.suptitle("Sample Images per Pathology Class", fontsize=14, fontweight='bold')
plt.tight_layout()
save_path = os.path.join(EDA_DIR, "05_sample_images.png")
plt.savefig(save_path, dpi=100, bbox_inches='tight')
plt.show()
print(f"Saved → {save_path}")

# %% [markdown]
# ## 4. Data Split & Preprocessing Pipeline

# %%
# ── Train / Validation / Test split ───────────────────────────────────────────
filenames      = df['Image Index'].values
labels_encoded = np.stack(df['encoded'].values)

num_samples = len(filenames)
indices     = np.arange(num_samples)
np.random.shuffle(indices)

train_end = int(TRAIN_RATIO * num_samples)
val_end   = train_end + int(VAL_RATIO * num_samples)

train_idx = indices[:train_end]
val_idx   = indices[train_end:val_end]
test_idx  = indices[val_end:]

train_filenames, train_labels = filenames[train_idx], labels_encoded[train_idx]
val_filenames,   val_labels   = filenames[val_idx],   labels_encoded[val_idx]
test_filenames,  test_labels  = filenames[test_idx],  labels_encoded[test_idx]

print(f"Split summary (total: {num_samples:,})")
print(f"  Train      : {len(train_idx):>6,}  ({len(train_idx)/num_samples*100:.1f}%)")
print(f"  Validation : {len(val_idx):>6,}  ({len(val_idx)/num_samples*100:.1f}%)")
print(f"  Test       : {len(test_idx):>6,}  ({len(test_idx)/num_samples*100:.1f}%)")

# ── Visualise split ────────────────────────────────────────────────────────────
fig, ax = plt.subplots(figsize=(5, 5))
ax.pie(
    [len(train_idx), len(val_idx), len(test_idx)],
    labels=[f'Train\n({len(train_idx):,})', f'Val\n({len(val_idx):,})', f'Test\n({len(test_idx):,})'],
    autopct='%1.1f%%', startangle=90,
    colors=['#4C72B0', '#55A868', '#DD8452']
)
ax.set_title("Data Split Distribution", fontsize=12, fontweight='bold')
plt.tight_layout()
save_path = os.path.join(EDA_DIR, "06_data_split.png")
plt.savefig(save_path, dpi=150, bbox_inches='tight')
plt.show()
print(f"Saved → {save_path}")

# %%
# ── Preprocessing & augmentation pipeline ─────────────────────────────────────
def preprocess_image(filename: tf.Tensor, label: tf.Tensor, training: bool = True):
    """
    Load, decode, resize, normalise and (optionally) augment a chest X-ray image.

    Parameters
    ----------
    filename : tf.Tensor (string)  — image filename within IMAGE_DIR
    label    : tf.Tensor           — multi-hot encoded label vector
    training : bool                — if True, apply random augmentation

    Returns
    -------
    img   : tf.Tensor  (IMG_SIZE x IMG_SIZE x CHANNELS, float32, ImageNet-normalised)
    label : tf.Tensor
    """
    img_path = tf.strings.join([IMAGE_DIR, filename], separator=os.sep)
    img = tf.io.read_file(img_path)
    img = tf.image.decode_png(img, channels=CHANNELS)
    img = tf.image.convert_image_dtype(img, tf.float32)

    if training:
        img = tf.image.resize(img, [int(IMG_SIZE * 1.15), int(IMG_SIZE * 1.15)])
        img = tf.image.random_crop(img, size=[IMG_SIZE, IMG_SIZE, CHANNELS])
        img = tf.image.random_flip_left_right(img)
        img = tf.image.random_brightness(img, max_delta=0.10)
        img = tf.image.random_contrast(img, lower=0.90, upper=1.10)
    else:
        img = tf.image.resize(img, [IMG_SIZE, IMG_SIZE])

    img = (img - IMAGENET_MEAN) / IMAGENET_STD
    return img, label


def build_dataset(fnames, lbls, training: bool = True) -> tf.data.Dataset:
    """Build a batched, prefetched tf.data.Dataset from filenames and labels."""
    ds = tf.data.Dataset.from_tensor_slices((fnames, lbls))
    ds = ds.map(
        lambda f, l: preprocess_image(f, l, training=training),
        num_parallel_calls=tf.data.AUTOTUNE
    )
    if training:
        ds = ds.shuffle(buffer_size=1000, seed=SEED)
    return ds.batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)


train_ds = build_dataset(train_filenames, train_labels, training=True)
val_ds   = build_dataset(val_filenames,   val_labels,   training=False)
test_ds  = build_dataset(test_filenames,  test_labels,  training=False)

print("tf.data pipelines ready.")
print(f"  train_ds : {len(train_filenames):,} images")
print(f"  val_ds   : {len(val_filenames):,} images")
print(f"  test_ds  : {len(test_filenames):,} images")

# %%
# ── Preprocessing visualisation ───────────────────────────────────────────────
example_filename = df['Image Index'].iloc[0]
example_label    = df['encoded'].iloc[0]

img_train, _ = preprocess_image(example_filename, example_label, training=True)
img_val,   _ = preprocess_image(example_filename, example_label, training=False)

orig_path = tf.strings.join([IMAGE_DIR, example_filename], separator=os.sep)
orig_img  = tf.image.convert_image_dtype(
    tf.image.decode_png(tf.io.read_file(orig_path), channels=CHANNELS), tf.float32
)

def denorm(img):
    return tf.clip_by_value(img * IMAGENET_STD + IMAGENET_MEAN, 0, 1)

fig, axes = plt.subplots(1, 3, figsize=(14, 4))
axes[0].imshow(orig_img);           axes[0].set_title("Original",          fontsize=11)
axes[1].imshow(denorm(img_train));  axes[1].set_title("Augmented (train)", fontsize=11)
axes[2].imshow(denorm(img_val));    axes[2].set_title("Resized (val/test)",fontsize=11)
for ax in axes: ax.axis('off')
plt.suptitle("Preprocessing Comparison", fontsize=13, fontweight='bold')
plt.tight_layout()
save_path = os.path.join(EDA_DIR, "07_preprocessing_comparison.png")
plt.savefig(save_path, dpi=150, bbox_inches='tight')
plt.show()
print(f"Saved → {save_path}")

# %% [markdown]
# ## 5. Model Architecture
#
# ### 5.1 DenseNet-121 with Custom Classification Head
#
# DenseNet-121 pre-trained on ImageNet is used as the backbone. All layers up to `conv5_block16_concat` are frozen; the final dense block and custom head are trainable.

# %%
# ── Build model ────────────────────────────────────────────────────────────────
base_model = DenseNet121(
    weights='imagenet',
    include_top=False,
    input_shape=(IMG_SIZE, IMG_SIZE, CHANNELS)
)

feature_extractor = Model(
    inputs=base_model.input,
    outputs=base_model.get_layer(FINETUNE_FROM).output,
    name="densenet121_backbone"
)

x       = feature_extractor.output
x       = GlobalAveragePooling2D(name="gap")(x)
x       = Dropout(DROPOUT_RATE, name="dropout")(x)
outputs = Dense(num_labels, activation='sigmoid', name="predictions")(x)

model = Model(inputs=base_model.input, outputs=outputs, name="ChestSight")

# ── Selective layer freezing ───────────────────────────────────────────────────
freeze = True
for layer in model.layers:
    if layer.name == FINETUNE_FROM:
        freeze = False
    layer.trainable = not freeze

trainable   = sum(1 for l in model.layers if l.trainable)
frozen      = len(model.layers) - trainable
print(f"Total layers     : {len(model.layers)}")
print(f"Trainable layers : {trainable}")
print(f"Frozen layers    : {frozen}")

# %%
model.compile(
    optimizer=optimizers.Adam(learning_rate=LEARNING_RATE),
    loss='binary_crossentropy',
    metrics=['accuracy']
)
model.summary()

# %% [markdown]
# ## 6. Training
#
# Training artefacts are saved to `results/training/` and model weights to `results/models/`.

# %%
# ── Callbacks ──────────────────────────────────────────────────────────────────
lr_scheduler = callbacks.ReduceLROnPlateau(
    monitor='val_loss', factor=0.1, patience=3, verbose=1, min_lr=1e-7
)
checkpoint = callbacks.ModelCheckpoint(
    MODEL_PATH, monitor='val_loss', save_best_only=True,
    save_weights_only=True, verbose=1
)
early_stop = callbacks.EarlyStopping(
    monitor='val_loss', patience=5, restore_best_weights=True, verbose=1
)

# ── Train ──────────────────────────────────────────────────────────────────────
history = model.fit(
    train_ds,
    epochs=EPOCHS,
    validation_data=val_ds,
    callbacks=[lr_scheduler, checkpoint, early_stop]
)

# ── Save training history as CSV ───────────────────────────────────────────────
history_df = pd.DataFrame(history.history)
history_csv = os.path.join(TRAINING_DIR, "training_history.csv")
history_df.to_csv(history_csv, index_label="epoch")
print(f"\nTraining history saved → {history_csv}")
print(f"Model weights saved    → {MODEL_PATH}")

# %%
# ── Training curves ────────────────────────────────────────────────────────────
fig, axes = plt.subplots(1, 2, figsize=(14, 4))

axes[0].plot(history.history['loss'],     label='Train',      color='#4C72B0', linewidth=2)
axes[0].plot(history.history['val_loss'], label='Validation', color='#DD8452', linewidth=2)
axes[0].set_xlabel("Epoch"); axes[0].set_ylabel("Loss")
axes[0].set_title("Training vs Validation Loss", fontweight='bold')
axes[0].legend(); sns.despine(ax=axes[0])

axes[1].plot(history.history['accuracy'],     label='Train',      color='#4C72B0', linewidth=2)
axes[1].plot(history.history['val_accuracy'], label='Validation', color='#DD8452', linewidth=2)
axes[1].set_xlabel("Epoch"); axes[1].set_ylabel("Accuracy")
axes[1].set_title("Training vs Validation Accuracy", fontweight='bold')
axes[1].legend(); sns.despine(ax=axes[1])

plt.tight_layout()
save_path = os.path.join(TRAINING_DIR, "training_curves.png")
plt.savefig(save_path, dpi=150, bbox_inches='tight')
plt.show()
print(f"Saved → {save_path}")

# %% [markdown]
# ## 7. Evaluation
#
# Evaluation results are saved to `results/evaluation/`.

# %%
# ── Collect predictions ────────────────────────────────────────────────────────
y_true_list, y_pred_list = [], []

for images, lbls in val_ds:
    preds        = model.predict(images, verbose=0)
    preds_binary = (preds > 0.5).astype(int)
    y_true_list.extend(lbls.numpy())
    y_pred_list.extend(preds_binary)

y_true = np.array(y_true_list)
y_pred = np.array(y_pred_list)

print(f"Evaluation set : {len(y_true):,} samples  |  shape: {y_true.shape}")

# %% [markdown]
# ### 7.1 Classification Report

# %%
report_str  = classification_report(y_true, y_pred, target_names=all_labels, zero_division=0)
report_dict = classification_report(y_true, y_pred, target_names=all_labels,
                                    zero_division=0, output_dict=True)

print(report_str)

# Save as CSV
report_df = pd.DataFrame(report_dict).transpose()
report_csv = os.path.join(EVALUATION_DIR, "classification_report.csv")
report_df.to_csv(report_csv)
print(f"Saved → {report_csv}")

# Save as text
report_txt = os.path.join(EVALUATION_DIR, "classification_report.txt")
with open(report_txt, 'w') as f:
    f.write(report_str)
print(f"Saved → {report_txt}")

# %% [markdown]
# ### 7.2 Per-class IoU and Dice Coefficient

# %%
def calculate_metrics(y_true: np.ndarray, y_pred: np.ndarray, labels: list) -> pd.DataFrame:
    """
    Calculate per-class IoU (Jaccard), Dice (F1), Precision, and Recall.

    Returns pd.DataFrame indexed by label.
    """
    rows = []
    for i, label in enumerate(labels):
        tp = np.sum((y_true[:, i] == 1) & (y_pred[:, i] == 1))
        fp = np.sum((y_true[:, i] == 0) & (y_pred[:, i] == 1))
        fn = np.sum((y_true[:, i] == 1) & (y_pred[:, i] == 0))

        precision = tp / (tp + fp) if (tp + fp) > 0 else 0.0
        recall    = tp / (tp + fn) if (tp + fn) > 0 else 0.0
        iou       = jaccard_score(y_true[:, i], y_pred[:, i], zero_division=0)
        dice      = f1_score(y_true[:, i],      y_pred[:, i], zero_division=0)

        rows.append({
            'Label'    : label,
            'IoU'      : round(iou,       4),
            'Dice'     : round(dice,      4),
            'Precision': round(precision, 4),
            'Recall'   : round(recall,    4),
        })

    return pd.DataFrame(rows).set_index('Label')


metrics_df  = calculate_metrics(y_true, y_pred, all_labels)
metrics_csv = os.path.join(EVALUATION_DIR, "per_class_metrics.csv")
metrics_df.to_csv(metrics_csv)

print(metrics_df.to_string())
print(f"\n── Aggregate Metrics ────────────────────────────────────────────────────────")
print(f"  Mean IoU       : {metrics_df['IoU'].mean():.4f}")
print(f"  Mean Dice      : {metrics_df['Dice'].mean():.4f}")
print(f"  Mean Precision : {metrics_df['Precision'].mean():.4f}")
print(f"  Mean Recall    : {metrics_df['Recall'].mean():.4f}")
print(f"\nSaved → {metrics_csv}")

# ── Save aggregate summary JSON ────────────────────────────────────────────────
summary = {
    "mean_iou"       : round(float(metrics_df['IoU'].mean()), 4),
    "mean_dice"      : round(float(metrics_df['Dice'].mean()), 4),
    "mean_precision" : round(float(metrics_df['Precision'].mean()), 4),
    "mean_recall"    : round(float(metrics_df['Recall'].mean()), 4),
}
summary_path = os.path.join(EVALUATION_DIR, "aggregate_metrics.json")
with open(summary_path, 'w') as f:
    json.dump(summary, f, indent=2)
print(f"Saved → {summary_path}")

# %% [markdown]
# ### 7.3 Per-class Metrics Bar Chart

# %%
fig, axes = plt.subplots(1, 2, figsize=(16, 5))

metrics_df[['IoU', 'Dice']].plot(kind='bar', ax=axes[0],
    color=['#4C72B0', '#DD8452'], edgecolor='white', linewidth=0.5)
axes[0].set_title("Per-class IoU and Dice Coefficient", fontweight='bold')
axes[0].set_xlabel("Pathology"); axes[0].set_ylabel("Score")
axes[0].tick_params(axis='x', rotation=45)
axes[0].legend(loc='upper right'); sns.despine(ax=axes[0])

metrics_df[['Precision', 'Recall']].plot(kind='bar', ax=axes[1],
    color=['#55A868', '#C44E52'], edgecolor='white', linewidth=0.5)
axes[1].set_title("Per-class Precision and Recall", fontweight='bold')
axes[1].set_xlabel("Pathology"); axes[1].set_ylabel("Score")
axes[1].tick_params(axis='x', rotation=45)
axes[1].legend(loc='upper right'); sns.despine(ax=axes[1])

plt.tight_layout()
save_path = os.path.join(EVALUATION_DIR, "per_class_metrics_chart.png")
plt.savefig(save_path, dpi=150, bbox_inches='tight')
plt.show()
print(f"Saved → {save_path}")

# %% [markdown]
# ### 7.4 Label Correlation in Predictions

# %%
pred_df  = pd.DataFrame(y_true, columns=all_labels)
corr_mat = pred_df.corr()

fig, ax = plt.subplots(figsize=(14, 11))
sns.heatmap(
    corr_mat, annot=True, fmt=".2f", cmap='coolwarm',
    center=0, linewidths=0.5, annot_kws={"size": 7}, ax=ax
)
ax.set_title("Correlation Matrix — True Labels (Validation Set)",
             fontsize=14, fontweight='bold', pad=12)
plt.tight_layout()
save_path = os.path.join(EVALUATION_DIR, "label_correlation_matrix.png")
plt.savefig(save_path, dpi=150, bbox_inches='tight')
plt.show()
print(f"Saved → {save_path}")

# %% [markdown]
# ## 8. Explainability — Grad-CAM
#
# Grad-CAM heatmaps are saved to `results/explainability/`.

# %%
def load_preprocess_image(img_path: str,
                          target_size: tuple = (IMG_SIZE, IMG_SIZE)) -> tf.Tensor:
    """Load and preprocess a single image for inference (returns batch of 1)."""
    img = tf.io.read_file(img_path)
    img = tf.image.decode_png(img, channels=CHANNELS)
    img = tf.image.convert_image_dtype(img, tf.float32)
    img = tf.image.resize(img, target_size)
    img = (img - IMAGENET_MEAN) / IMAGENET_STD
    return tf.expand_dims(img, axis=0)


def get_gradcam_heatmap(img_array: tf.Tensor,
                        model: tf.keras.Model,
                        last_conv_layer_name: str,
                        pred_index: int = None) -> np.ndarray:
    """
    Compute a Grad-CAM heatmap for the given image and target class.

    Parameters
    ----------
    img_array            : tf.Tensor shape (1, H, W, C)
    model                : tf.keras.Model
    last_conv_layer_name : str   — target convolutional layer name
    pred_index           : int   — target class; defaults to argmax

    Returns
    -------
    heatmap : np.ndarray  (h, w) in [0, 1]
    """
    conv_layer = model.get_layer(last_conv_layer_name)
    grad_model = tf.keras.models.Model(
        inputs=model.inputs,
        outputs=[conv_layer.output, model.output]
    )

    with tf.GradientTape() as tape:
        conv_outputs, predictions = grad_model(img_array)
        if pred_index is None:
            pred_index = int(tf.argmax(predictions[0]))
        target = predictions[:, pred_index]

    grads        = tape.gradient(target, conv_outputs)
    pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))

    heatmap = conv_outputs[0] @ pooled_grads[..., tf.newaxis]
    heatmap = tf.squeeze(heatmap)
    heatmap = tf.maximum(heatmap, 0) / (tf.reduce_max(heatmap) + 1e-8)
    return heatmap.numpy()


def display_and_save_gradcam(img_path: str,
                              heatmap: np.ndarray,
                              predicted_class: str,
                              alpha: float = 0.4,
                              threshold: float = 0.5) -> str:
    """
    Display and save Grad-CAM visualisation panel.

    Returns path to saved file.
    """
    orig_img      = cv2.cvtColor(cv2.imread(img_path), cv2.COLOR_BGR2RGB)
    heatmap_sized = cv2.resize(heatmap, (orig_img.shape[1], orig_img.shape[0]))
    heatmap_color = cv2.cvtColor(
        cv2.applyColorMap(np.uint8(255 * heatmap_sized), cv2.COLORMAP_JET),
        cv2.COLOR_BGR2RGB
    )
    overlay     = np.uint8(heatmap_color * alpha + orig_img)
    pseudo_mask = (heatmap_sized > threshold).astype(np.uint8) * 255

    fig, axes = plt.subplots(1, 4, figsize=(18, 4))
    panels = [
        (orig_img,      "Original image",          'gray'),
        (heatmap_sized, "Grad-CAM heatmap",         'jet'),
        (overlay,       "Overlay",                  None),
        (pseudo_mask,   "Pseudo-segmentation mask", 'gray'),
    ]
    for ax, (img, title, cmap) in zip(axes, panels):
        ax.imshow(img, cmap=cmap)
        ax.set_title(title, fontsize=10, fontweight='bold')
        ax.axis('off')

    plt.suptitle(f"Grad-CAM  |  Predicted class: {predicted_class}",
                 fontsize=12, fontweight='bold')
    plt.tight_layout()

    safe_name = predicted_class.replace(' ', '_').replace('/', '-')
    save_path = os.path.join(EXPLAINABILITY_DIR, f"gradcam_{safe_name}.png")
    plt.savefig(save_path, dpi=150, bbox_inches='tight')
    plt.show()
    return save_path

# %%
# ── Run Grad-CAM on a sample test image ───────────────────────────────────────
sample_filename = test_filenames[0]
sample_img_path = os.path.join(IMAGE_DIR, sample_filename)

img_array = load_preprocess_image(sample_img_path)

raw_preds      = model.predict(img_array, verbose=0)[0]
top_class_idx  = int(np.argmax(raw_preds))
top_class_name = all_labels[top_class_idx]
top_class_prob = raw_preds[top_class_idx]

print(f"Sample image   : {sample_filename}")
print(f"Top prediction : {top_class_name}  (p = {top_class_prob:.3f})")

heatmap   = get_gradcam_heatmap(img_array, model, FINETUNE_FROM, pred_index=top_class_idx)
save_path = display_and_save_gradcam(sample_img_path, heatmap, predicted_class=top_class_name)
print(f"Saved → {save_path}")

# %%
# ── Run Grad-CAM across all predicted classes (top-5) ─────────────────────────
top5_indices = np.argsort(raw_preds)[::-1][:5]

print("Top-5 predictions and Grad-CAM saved:")
for idx in top5_indices:
    class_name = all_labels[idx]
    prob       = raw_preds[idx]
    heatmap    = get_gradcam_heatmap(img_array, model, FINETUNE_FROM, pred_index=int(idx))
    saved      = display_and_save_gradcam(sample_img_path, heatmap,
                                          predicted_class=class_name)
    print(f"  {class_name:<25} p={prob:.3f}  →  {saved}")

# %% [markdown]
# ## 9. Results Summary
#
# ### Saved Artefacts
#
# | Folder | Files |
# |---|---|
# | `results/eda/` | `01_label_distribution.png`, `02_multilabel_distribution.png`, `03_demographics.png`, `04_cooccurrence_heatmap.png`, `05_sample_images.png`, `06_data_split.png`, `07_preprocessing_comparison.png`, `label_frequencies.csv`, `label_cooccurrence_correlation.csv` |
# | `results/training/` | `training_curves.png`, `training_history.csv` |
# | `results/evaluation/` | `classification_report.txt`, `classification_report.csv`, `per_class_metrics.csv`, `aggregate_metrics.json`, `per_class_metrics_chart.png`, `label_correlation_matrix.png` |
# | `results/explainability/` | `gradcam_<class>.png` (one per predicted class) |
# | `results/models/` | `chestsight_best.weights.h5` |
#
# ### Baseline Performance
#
# | Metric | Value |
# |---|---|
# | Micro-avg F1 | 0.49 |
# | No Finding F1 | 0.72 |
# | Macro-avg F1 | 0.05 |
#
# ### Recommended Next Steps
#
# 1. Replace BCE loss with **Focal Loss** to address class imbalance
# 2. Apply **per-class threshold optimisation** on validation set
# 3. Re-split at **patient level** to eliminate data leakage
# 4. Report **per-class AUC-ROC** (standard NIH benchmark metric)
# 5. Upgrade to **Grad-CAM++** for sharper localisation
#
# ### References
#
# - Wang et al. (2017). *ChestX-ray8.* CVPR.
# - Rajpurkar et al. (2017). *CheXNet.* arXiv:1711.05225.
# - Huang et al. (2017). *Densely Connected Convolutional Networks.* CVPR.
# - Selvaraju et al. (2017). *Grad-CAM.* ICCV.
# - Lin et al. (2017). *Focal Loss.* ICCV.
